# %%
from PIL import ImageGrab
import pyautogui
import time

# %%
### function to check if RGB is white (r,g,b > 220)
### compare each element of a RBG tuple with 220
### arguments are:
### RGB - (r,g,b) - color code
def is_white(RGB):
    if RGB[0] > 220 and RGB[1] > 220 and RGB[2] > 220:
        return True
    else:
        return False

# %%
### fonction to check how many white sticks there is
### arguments are:
### hexagone - [(x1,y1),(x2,y2),...,(x6,y6)] - coords of white sticks to check
def check_figure(hexagone):
    counter = 0
    idx = []
    for stick_idx, stick in enumerate(hexagone):
        if is_white(stick):
            idx.append(stick_idx)
            counter += 1
    return counter, idx

# %%
### function to click mouse on coords of a hexa center
### arguments are:
### coords - (x,y) to click on
### l_r - 'left'/'right' for LMB/RMB
### x - times to click
def mouse_click(coords, l_r, x):
#     x = coords[0]
#     y = coords[1]      
#     for i in range(x):
#         pyautogui.click(x=x, y=y,button=l_r)
#         time.sleep(15)
    print(f"click on {coords} with {l_r[0].upper()}MB {x} times")

# %%
### dictionary contains list of tuples (x,y) for correct positions anti-clockwise 
### (first 3 tuples are coordinats of correct positions)
### center coords start with top_left
dict_positions = {'top_left':[(2351,727),(2501,732),(2584,585),(2509,443),(2361,448),(2281,590)],
                  'left':[(2288,1098),(2361,973),(2292,836),(2154,829),(2089,955),(2152,1088)],
                  'bottom_left':[(2558,1374),(2487,1231),(2342,1213),(2270,1335),(2340,1473),(2478,1496)],
                  'bottom_right':[(2945,1280),(2770,1262),(2683,1392),(2755,1543),(2930,1570),(3025,1435)],
                  'right':[(3035,860),(2935,1008),(3021,1170),(3211,1190),(3322,1036),(3230,868)],
                  'top_right':[(2712,586),(2788,738),(2970,740),(3070,580),(2985,423),(2804,430)],
                  'center':[(2560,844),(2480,985),(2548,1128),(2710,1140),(2800,1000),(2722,855)]}
# dictionary contains list of tuples (x,y) for hexagon centers to click on
dict_cents = {'top_left':(2430,590),
              'left':(2220,965),
              'bottom_left':(2410,1360),
              'bottom_right':(2850,1415),
              'right':(3125,1025),
              'top_right':(2885,583),
              'center':(2633,991)}

# %%
### training dictionary
dict_positions = {'top_left':[(1808, 490),(1885, 489),(1924, 423),(1885, 357),(1807, 356),(1768, 423)],
                  'left':[(1781, 669),(1820, 605),(1781, 538),(1705, 538),(1665, 604),(1703, 673)],
                  'bottom_left':[(1924, 783),(1885, 716),(1808, 717),(1768, 783),(1807, 851),(1886, 850)],
                  'bottom_right':[(2093, 717),(2016, 714),(1978, 783),(2016, 851),(2093, 850),(2132, 783)],
                  'right':[(2119, 536),(2080, 602),(2120, 671),(2198, 670),(2237, 601),(2196, 538)],
                  'top_right':[(1976, 423),(2015, 491),(2095, 489),(2131, 422),(2093, 356),(2014, 356)],
                  'center':[(1912, 536),(1873, 606),(1910, 670),(1989, 673),(2028, 606),(1988, 534)]}
dict_cents = {'top_left':(1845, 422),
              'left':(1741, 602),
              'bottom_left':(1846, 781),
              'bottom_right':(2053, 782),
              'right':(2159, 604),
              'top_right':(2052, 421),
              'center':(1949, 600)}

# %%
### function to grab a screenshot
### *not implemented* arguments:
### faction - 'corpus'/'greneer'/'orokin'/'narmer'
### returns screen_dict - dictionary with RGB tuples for pre-specified faction unique pixels
# def grab_screenshot():
    ### Corpus
    ###########
    ### Greneer
    ###########
    ### Orokin
    ###########
    ### Narmer
    ###########
time.sleep(5)
## Capture the screen or a specific region
## and conform 2 dicts with RGBs
screenshot = ImageGrab.grab()
screen_dict = {'top_left':[],
               'left':[],
               'bottom_left':[],
               'bottom_right':[],
               'right':[],
               'top_right':[],
               'center':[]}
screen_dict_cents = {'top_left':[],
                     'left':[],
                     'bottom_left':[],
                     'bottom_right':[],
                     'right':[],
                     'top_right':[],
                     'center':[]}
for i in dict_positions:
    for j in dict_positions[i]:
        # Define the coordinates of the pixel you want to retrieve
        x = j[0]
        y = j[1]
        pixel_color = screenshot.getpixel((x, y))
        screen_dict[i].append(pixel_color)
    # Define the coordinates of the pixel you want to retrieve
    x = dict_cents[i][0]
    y = dict_cents[i][1]
    pixel_color = screenshot.getpixel((x, y))
    screen_dict_cents[i].append(pixel_color)
print(screen_dict)
print(screen_dict_cents)
# return screen_dict, screen_dict_cents
# Out:
# {'top_left': [(24, 48, 62), (20, 43, 56), (21, 44, 57), (23, 47, 61), (255, 255, 255), (23, 46, 60)], 'left': [(17, 35, 45), (17, 35, 45), (17, 35, 45), (17, 35, 45), (17, 35, 45), (17, 35, 45)], 'bottom_left': [(17, 35, 45), (17, 35, 45), (17, 35, 45), (17, 35, 45), (17, 35, 45), (17, 35, 45)], 'bottom_right': [(24, 48, 62), (22, 46, 60), (23, 46, 60), (23, 47, 62), (255, 255, 255), (21, 44, 57)], 'right': [(20, 43, 55), (22, 44, 57), (255, 255, 255), (21, 44, 57), (19, 40, 51), (23, 47, 62)], 'top_right': [(23, 46, 60), (23, 47, 61), (23, 47, 62), (19, 40, 51), (255, 255, 255), (22, 45, 59)], 'center': [(17, 35, 45), (17, 35, 45), (17, 35, 45), (17, 35, 45), (17, 35, 45), (17, 35, 45)]}
# {'top_left': [(255, 255, 255)], 'left': [(17, 35, 45)], 'bottom_left': [(17, 35, 45)], 'bottom_right': [(255, 255, 255)], 'right': [(255, 255, 255)], 'top_right': [(255, 255, 255)], 'center': [(17, 35, 45)]}

# %%
### LMB - clockwise; RMB - anti-clockwise 
### indeces of 'whites' are starting with 0 and continuing anti-clockwise. And 1 is always the stick to the center
##################################################################################################################
### make a screenshot
# screen_dict, screen_dict_cents = grab_screenshot()

figure_list = []
### first iteration we rotate triples, wide- and sharp-angles    
for hexa_id, hexa in enumerate(dict_cents):
    ### if center is white then there is a moveable hexa    
    if is_white(screen_dict_cents[hexa][0]):
        ### get number and indeces of "whites"
        counter, idx = check_figure(screen_dict[hexa])
        ### firstly, we rotate all triples and wide-angles, as they can be adjusted only for one possible position
        ### for a triple
        print(hexa, idx, sep=': ')
        if counter == 3 and hexa != 'center':
            ### add a hexa id to the list, so sharp-angles and 1-sticks could be adjusted
            figure_list.append('T')
            ### if 'white' are 0,1,2 - it is the right position
            if idx == [0,1,2]:
                print('right position')
            ### if 'white' are 1 RMB away
            elif idx == [1,2,3]:
                mouse_click(dict_cents[hexa],'left', 1)
            ### if 'white' are 1 LMB away:
            elif idx == [0,1,5]:
                mouse_click(dict_cents[hexa],'right', 1)
            ### if 'white' are 2 RMB away:
            elif idx == [2,3,4]:
                mouse_click(dict_cents[hexa],'left', 2)
            ### if 'white' are 2 LMB away:
            elif idx == [0,4,5]:
                mouse_click(dict_cents[hexa],'right', 2) 
            ### if 'white' are 3 LMB away:
            elif idx == [3,4,5]:
                mouse_click(dict_cents[hexa],'left', 3)
        ### if difference between indeces > 1 and < 5, then it's a wide-angle 
        elif (counter == 2 and hexa != 'center' and 
              (5 > idx[1]-idx[0] > 1)):
            ### add a hexa id to the list, so sharp-angles and 1-sticks could be adjusted
            figure_list.append('W')
            ### if 'white' are 0,1,2 - it is the right position
            if idx == [0,2]:
                print('right position')
            ### if 'white' are 1 RMB away
            elif idx == [1,3]:
                mouse_click(dict_cents[hexa],'left', 1)
            ### if 'white' are 1 LMB away:
            elif idx == [1,5]:
                mouse_click(dict_cents[hexa],'right', 1)
            ### if 'white' are 2 RMB away:
            elif idx == [2,4]:
                mouse_click(dict_cents[hexa],'left', 2)
            ### if 'white' are 2 LMB away:
            elif idx == [0,4]:
                mouse_click(dict_cents[hexa],'right', 2) 
            ### if 'white' are 3 LMB away:
            elif idx == [3,5]:
                mouse_click(dict_cents[hexa],'left', 3)
        ### then we rotate sharp-angles so 1 stick is always positioned on index 1 (facing center hexa)
        ### and the other stick facing the closest wide-angle or the opposite
        ### for a sharp-angle
        elif (counter == 2 and hexa != 'center' and
              (idx[1]-idx[0] == 1 or idx[1]-idx[0] == 5)):
            ### if the previous hexa is not a wide-angle or a triple, the then next must be
            if (figure_list[-1] != 'W') or (figure_list[-1] != 'T'):                
                ### if 'white' are 0,1 - it is the right position
                if idx == [0,1]:
                    print('right position')
                ### if 'white' are 1 RMB away
                elif idx == [0,5]:
                    mouse_click(dict_cents[hexa],'right', 1)
                ### if 'white' are 1 LMB away
                elif idx == [1,2]:
                    mouse_click(dict_cents[hexa],'left', 1)
                ### if 'white' are 2 RMB away
                elif idx == [4,5]:
                    mouse_click(dict_cents[hexa],'right', 2)
                ### if 'white' are 2 LMB away
                elif idx == [2,3]:
                    mouse_click(dict_cents[hexa],'left', 2)
                ### if 'white' are 3 LMB away
                elif idx == [3,4]:
                    mouse_click(dict_cents[hexa],'left', 3)
                figure_list.append('Sh_n')
            else:
                ### if the previous hexa is a wide-angle
                ### if 'white' are 1,2 - it is the right position
                if idx == [1,2]:
                    print('right position')
                ### if 'white' are 1 RMB away
                elif idx == [0,1]:
                    mouse_click(dict_cents[hexa],'right', 1)
                ### if 'white' are 1 LMB away
                elif idx == [2,3]:
                    mouse_click(dict_cents[hexa],'left', 1)
                ### if 'white' are 2 RMB away
                elif idx == [0,5]:
                    mouse_click(dict_cents[hexa],'right', 2)
                ### if 'white' are 2 LMB away
                elif idx == [3,4]:
                    mouse_click(dict_cents[hexa],'left', 2)
                ### if 'white' are 3 LMB away
                elif idx == [4,5]:
                    mouse_click(dict_cents[hexa],'left', 3)   
                figure_list.append('Sh_p')
        ### add 1-sticks to a list
        elif counter == 1:   
            figure_list.append('St')
        ### add center hexa to a list
        elif hexa == 'center':
            figure_list.append('C')
    ### add a skip to a figure_list
    else:
        figure_list.append('E')
### then we rotate 1-sticks so it is positioned to the nearest wide- or sharp-angle or a stick if any
### else it is rotated to the 1st index (to the center)
for hexa_id, hexa in enumerate(dict_cents):
    ### if center is white then there is a moveable hexa    
    if is_white(screen_dict_cents[hexa][0]):
        ### get number and indeces of "whites"
        counter, idx = check_figure(screen_dict[hexa])
        if counter == 1:
            ### if the previous hexa is a wide-angle, a triple or a converging sharp-angle
            if ((figure_list[hexa_id-1] if hexa_id > 0 else figure_list[-1]) == 'W' or 
                (figure_list[hexa_id-1] if hexa_id > 0 else figure_list[-1]) == 'T' or
                (figure_list[hexa_id-1] if hexa_id > 0 else figure_list[-1]) == 'Sh_n'):
                if idx == [2]:
                    print('right position')
                ### if 'white' are 1 RMB away
                elif idx == [1]:
                    mouse_click(dict_cents[hexa],'right', 1)
                ### if 'white' are 1 LMB away
                elif idx == [3]:
                    mouse_click(dict_cents[hexa],'left', 1)
                ### if 'white' are 2 RMB away
                elif idx == [0]:
                    mouse_click(dict_cents[hexa],'right', 2)
                ### if 'white' are 2 LMB away
                elif idx == [4]:
                    mouse_click(dict_cents[hexa],'left', 2)
                ### if 'white' are 3 LMB away
                elif idx == [5]:
                    mouse_click(dict_cents[hexa],'left', 3) 
            ### if the next hexa is a converging sharp-angle
            elif (figure_list[(hexa_id+1) % len(figure_list)] == 'W' or
                  figure_list[(hexa_id+1) % len(figure_list)] == 'T' or
                  figure_list[(hexa_id+1) % len(figure_list)] == 'Sh_p'):
                if idx == [0]:
                    print('right position')
                ### if 'white' are 1 RMB away
                elif idx == [5]:
                    mouse_click(dict_cents[hexa],'right', 1)
                ### if 'white' are 1 LMB away
                elif idx == [1]:
                    mouse_click(dict_cents[hexa],'left', 1)
                ### if 'white' are 2 RMB away
                elif idx == [4]:
                    mouse_click(dict_cents[hexa],'right', 2)
                ### if 'white' are 2 LMB away
                elif idx == [2]:
                    mouse_click(dict_cents[hexa],'left', 2)
                ### if 'white' are 3 LMB away
                elif idx == [3]:
                    mouse_click(dict_cents[hexa],'left', 3) 

### finally we rotate the center hexa
              
print(figure_list)
# Out:
# top_left: [4]
# bottom_right: [4]
# right: [2]
# top_right: [4]
# ['St', 'E', 'E', 'St', 'St', 'St', 'E']

# %%
print(dict_cents)
# Out:
# {'top_left': (1845, 422), 'left': (1741, 602), 'bottom_left': (1846, 781), 'bottom_right': (2053, 782), 'right': (2159, 604), 'top_right': (2052, 421), 'center': (1949, 600)}

# %%
my_list = ['a', 'b', 3, 4, 5]

for i in range(len(my_list)):
    if ((i + 1) % len(my_list) == 3 or (i + 1) % len(my_list) == 'b'):
        print(i)
# Out:
# 2

# %%
print(figure_list)
# Out:
# ['St', 'W', 'St']

# %%
print(hexa_id-1)
# Out:
# 4
